# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd
df_abalone=pd.read_csv("abalone.csv")
df_abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
#Lets check whether there are null values or not
df_abalone.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# No Null values are present

# %%
#Lets check the  Datatypes of each column
df_abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# All input variables other than sex is in float64

# %%
#Lets check correlation matrix
df_abalone.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
#Lets describe the abalone dataset
df_abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# As mean and median is almost the same, this means that there isnt any outliers

# %% [markdown]
# # Let us do some EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Sex",y="Rings",data=df_abalone)
plt.show()

# %%
abalone_final=pd.get_dummies(df_abalone,drop_first=True)
abalone_final
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings  Sex_I  Sex_M
# ...

# %%
sns.pairplot(abalone_final)

# %%
# heatmap

sns.heatmap(abalone_final)
# Out:
# <AxesSubplot:>

# %%
# plotting a hue plot

plt.rcParams['figure.figsize'] = (18, 8)
sns.boxplot(df_abalone['Rings'], df_abalone['Length'], hue = df_abalone['Sex'], palette = 'pastel')
plt.title('Rings vs length and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs length and sex')

# %%
# rings vs diameter and sex

plt.rcParams['figure.figsize'] = (20, 8)
sns.violinplot(df_abalone['Rings'], df_abalone['Diameter'], hue = df_abalone['Sex'], palette = 'Set1')
plt.title('Rings vs diameter and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs diameter and sex')

# %%
# rings vs height and sex

plt.rcParams['figure.figsize'] = (18, 8)
sns.boxenplot(df_abalone['Rings'], df_abalone['Height'], hue = df_abalone['Sex'], palette = 'Set2')
plt.title('Rings vs height and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs height and sex')

# %%
# ring vs weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.swarmplot(df_abalone['Rings'], df_abalone['Whole weight'])
plt.title('Rings vs weight')
# Out:
# Text(0.5, 1.0, 'Rings vs weight')

# %%
# ring vs shucked weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.swarmplot(df_abalone['Rings'], df_abalone['Shucked weight'], palette = 'dark')
plt.title('Rings vs shucked weight')
# Out:
# Text(0.5, 1.0, 'Rings vs shucked weight')

# %%
# ring vs viscera weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.stripplot(df_abalone['Rings'], df_abalone['Viscera weight'])
plt.title('Rings vs Viscera Weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Viscera Weight')

# %%
# ring vs shell weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.regplot(df_abalone['Rings'], df_abalone['Shell weight'])
plt.title('Rings vs Shell weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Shell weight')

# %%
#Lets check the skewness
abalone_final.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# Sex_I             0.765708
# Sex_M             0.557390
# dtype: float64

# %% [markdown]
# From above output it is clear that skewness is there

# %%
#Lets change the Object type into integer type
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df_abalone['Sex'] = le.fit_transform(df_abalone['Sex'])

df_abalone['Sex'].value_counts()

df_abalone = pd.get_dummies(df_abalone)

# %%
df_abalone.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
#Lets remove the outliers if present using z scores
from scipy.stats import zscore
z_scr=zscore(df_abalone)
print(df_abalone.shape)
abalone_new=df_abalone.loc[(abs(z_scr)<3).all(axis=1)]
print(abalone_new.shape)
# Out:
# (4177, 9)
# (4027, 9)

# %%
#Lets divide the dataset into input and output
df_x=abalone_new.drop(columns=["Rings"])
y=abalone_new[["Rings"]]

# %%
#Lets check the skewness
abalone_new.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# dtype: float64

# %% [markdown]
# Some skewness is present in Length, Diameter and Rings but rings is the target variable so we will not remove any skewness from it.

# %%
#Now lets remove the skewness
import numpy as np
for index in df_x.skew().index:
    if df_x.skew().loc[index]>0.5:
        df_x[index]=np.log1p(df_x[index])
    if df_x.skew().loc[index]<-0.5:
        df_x[index]=np.square(df_x[index])

# %%
#lets again check the skewness
df_x.skew()
# Out:
# Sex              -0.094886
# Length           -0.119420
# Diameter         -0.078925
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# dtype: float64

# %% [markdown]
# There isnt any skewness present now

# %%
#Lets do the preprocessing bring features to common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Lets use decision tree regressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,x,y)
# Out:
# r2 score corresponding to  42  is  0.10037195333607285
# r2 score corresponding to  43  is  0.009802139947131305
# r2 score corresponding to  44  is  0.09693304110820755
# r2 score corresponding to  45  is  0.15203640523530693
# r2 score corresponding to  46  is  0.01949968894013776
# r2 score corresponding to  47  is  0.17473020246757753
# r2 score corresponding to  48  is  0.05460884679953237
# r2 score corresponding to  49  is  0.1524223058125721
# r2 score corresponding to  50  is  0.16203221589524297
# r2 score corresponding to  51  is  0.2284202431545096
# r2 score corresponding to  52  is  0.14536938371050934
# r2 score corresponding to  53  is  -0.032815425160313216
# r2 score corresponding to  54  is  0.13457297084505715
# r2 score corresponding to  55  is  0.21436847454635644
# r2 score corresponding to  56  is  0.09808661104986804
# r2 score corresponding to  57  is  0.18398205502092568
# r2 score corresponding to  58  is  0.187597343030386
# ...

# %%
#lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5)
clf.fit(x, y)
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
#Lets use maxr2_score function
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,x,y)
# Out:
# r2 score corresponding to  42  is  0.5530537355933594
# r2 score corresponding to  43  is  0.5351038629771188
# r2 score corresponding to  44  is  0.5362796207866607
# r2 score corresponding to  45  is  0.5977268515021916
# r2 score corresponding to  46  is  0.5256438707671094
# r2 score corresponding to  47  is  0.5717389407814136
# r2 score corresponding to  48  is  0.49002932271555955
# r2 score corresponding to  49  is  0.5339071265079239
# r2 score corresponding to  50  is  0.5586456802979836
# r2 score corresponding to  51  is  0.5507361247508182
# r2 score corresponding to  52  is  0.5344365149633702
# r2 score corresponding to  53  is  0.4448244081100319
# r2 score corresponding to  54  is  0.4927874227427095
# r2 score corresponding to  55  is  0.548698488389219
# r2 score corresponding to  56  is  0.5157339468153606
# r2 score corresponding to  57  is  0.5705280563023343
# r2 score corresponding to  58  is  0.5831032238085498
# ...

# %% [markdown]
# It took very long time for Random Forest Regressor to perform

# %%
#Lets check the mean r2_score with random forest
from sklearn.model_selection import cross_val_score
cross_val_score(rfr,x,y,cv=10,scoring="r2").mean()
# Out:
# 0.42404523537728406

# %%
#Lets use KNN regressor but we will find the optimal value of n_neigbors using grid search
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
parameters = {"n_neighbors":range(2,30)}
clf = GridSearchCV(knr, parameters, cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'n_neighbors': 22}

# %%
#Lets use n_neighbors as found above and use maxr2_score function
knr=KNeighborsRegressor(n_neighbors=22)
r_state=maxr2_score(knr,x,y)
#KNN is giving same r2 score as random forest
# Out:
# r2 score corresponding to  42  is  0.48954401512884893
# r2 score corresponding to  43  is  0.5206875419862804
# r2 score corresponding to  44  is  0.5138089487196731
# r2 score corresponding to  45  is  0.5551824753007166
# r2 score corresponding to  46  is  0.524359885076996
# r2 score corresponding to  47  is  0.5134570762918489
# r2 score corresponding to  48  is  0.4805345103394404
# r2 score corresponding to  49  is  0.5234434610125077
# r2 score corresponding to  50  is  0.516174804404743
# r2 score corresponding to  51  is  0.5058000248635335
# r2 score corresponding to  52  is  0.49700512666928065
# r2 score corresponding to  53  is  0.45813907271376586
# r2 score corresponding to  54  is  0.48512477466280557
# r2 score corresponding to  55  is  0.5210748413391992
# r2 score corresponding to  56  is  0.4837978668191216
# r2 score corresponding to  57  is  0.5204569868791804
# r2 score corresponding to  58  is  0.5495862376531059
# ...

# %%
#Lets find mean r2 score using cross_val score function
cross_val_score(knr,x,y,cv=10,scoring="r2").mean()
#Here mean r2 score is better than random forest regressor
# Out:
# 0.422976297280234

# %%
#Lets use KNN regressor and save it as our final model
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

model = RandomForestClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# evaluation
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE :", rmse)

# r2 score
r2 = r2_score(y_test, y_pred)
print("R2 Score :", r2)
# Out:
# RMSE : 2.1941512939392154
# R2 Score : 0.38310618825136744

# %%
knr=KNeighborsRegressor(n_neighbors=22)
knr.fit(x_train,y_train)
y_pred=knr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred) )
# Out:
# RMSE is:  1.8892889853696033
# r2_score is:  0.54262327718546

# %%
import joblib 
  
# Save the model as a pickle in a file 
joblib.dump(knr, 'abalone_knn.pkl')
# Out:
# ['abalone_knn.pkl']
